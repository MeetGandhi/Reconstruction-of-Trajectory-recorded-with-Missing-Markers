# %%
# !git clone https://github.com/YuliaRubanova/latent_ode.git
# Out:
# Cloning into 'latent_ode'...
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 192 (delta 15), reused 23 (delta 8), pack-reused 153
# Receiving objects: 100% (192/192), 40.47 MiB | 13.15 MiB/s, done.
# Resolving deltas: 100% (108/108), done.

# %%
cd latent_ode/
# Out:
# /content/latent_ode

# %%
# !pip install git+https://github.com/rtqichen/torchdiffeq
# Out:
# ...
#   Cloning https://github.com/rtqichen/torchdiffeq to /tmp/pip-req-build-bnsrff2y
#   Running command git clone -q https://github.com/rtqichen/torchdiffeq /tmp/pip-req-build-bnsrff2y
# ...
#   Created wheel for torchdiffeq: filename=torchdiffeq-0.0.1-cp36-none-any.whl size=24103 sha256=c2788af4340215b1d44cb0831d7ce815238fe9a1e6d49bf98ddb3a25fe788677
#   Stored in directory: /tmp/pip-ephem-wheel-cache-lrg0a2lg/wheels/3f/76/69/01867bf3355c3bc8bae7e556b17b44c395b6cda5e76fd8ddc7
# Successfully built torchdiffeq
# ...

# %%
# !python3 run_models.py --niters 500 -n 1000 -l 10 --dataset activity  --latent-ode --z0-encoder rnn
# Out:
# Sampling dataset of 1000 training examples
# ...
# 21553152it [00:02, 10439611.80it/s]
# Processing ConfLongDemo_JSI.txt...
# Done!
# Dataset PersonActivity
#     Number of datapoints: 1000
#     Root Location: data/PersonActivity
#     Max length: 50
#     Reduce: average
#
# /content/latent_ode/run_models.py
# run_models.py --niters 500 -n 1000 -l 10 --dataset activity --latent-ode --z0-encoder rnn
# Computing loss... 0
# Experiment 61226
# Epoch 0001 [Test seq (cond on sampled tp)] | Loss 3236.343750 | Likelihood -3263.450928 | KL fp 3.8588 | FP STD 0.2144|
# KL coef: 0.0
# Train loss (one batch): 3714.36181640625
# Train CE loss (one batch): 0.0
# Test MSE: 0.6534
# Poisson likelihood: 0.0
# CE loss: 0.0
# Computing loss... 0
# Experiment 61226
# Epoch 0002 [Test seq (cond on sampled tp)] | Loss 2061.623779 | Likelihood -2090.360107 | KL fp 6.1135 | FP STD 0.2223|
# KL coef: 0.0
# Train loss (one batch): 1990.9617919921875
# Train CE loss (one batch): 0.0
# Test MSE: 0.4188
# ...

# %%
# !python3 run_models.py --niters 100 -n 1000 -l 10 --dataset activity  --ode-rnn
# Out:
# Sampling dataset of 1000 training examples
# Dataset PersonActivity
#     Number of datapoints: 1000
#     Root Location: data/PersonActivity
#     Max length: 50
#     Reduce: average
#
# /content/latent_ode/run_models.py
# run_models.py --niters 100 -n 1000 -l 10 --dataset activity --ode-rnn
# Computing loss... 0
# Experiment 97994
# Epoch 0001 [Test seq (cond on sampled tp)] | Loss 2186.749756 | Likelihood -2186.749756 | KL fp 0.0000 | FP STD 0.0000|
# KL coef: 0.0
# Train loss (one batch): 2137.5244140625
# Train CE loss (one batch): 0.0
# Test MSE: 0.4381
# Poisson likelihood: 0.0
# CE loss: 0.0
# Computing loss... 0
# Experiment 97994
# Epoch 0002 [Test seq (cond on sampled tp)] | Loss 1572.115234 | Likelihood -1572.115234 | KL fp 0.0000 | FP STD 0.0000|
# KL coef: 0.0
# Train loss (one batch): 1536.851318359375
# Train CE loss (one batch): 0.0
# Test MSE: 0.3152
# Poisson likelihood: 0.0
# CE loss: 0.0
# Computing loss... 0
# Experiment 97994
# ...

# %%
# !python3 run_models.py --niters 100 -n 1000 -l 10 --dataset activity  --rnn-vae
# Out:
# Sampling dataset of 1000 training examples
# Dataset PersonActivity
#     Number of datapoints: 1000
#     Root Location: data/PersonActivity
#     Max length: 50
#     Reduce: average
#
# /content/latent_ode/run_models.py
# run_models.py --niters 100 -n 1000 -l 10 --dataset activity --rnn-vae
# Computing loss... 0
# Experiment 5972
# Epoch 0001 [Test seq (cond on sampled tp)] | Loss 2796.520508 | Likelihood -2796.520508 | KL fp 1.2043 | FP STD 0.2903|
# KL coef: 0.0
# Train loss (one batch): 2931.590576171875
# Train CE loss (one batch): 0.0
# Test MSE: 0.5600
# Poisson likelihood: 0.0
# CE loss: 0.0
# Computing loss... 0
# Experiment 5972
# Epoch 0002 [Test seq (cond on sampled tp)] | Loss 2384.763428 | Likelihood -2384.763428 | KL fp 2.0541 | FP STD 0.1756|
# KL coef: 0.0
# Train loss (one batch): 2372.6953125
# Train CE loss (one batch): 0.0
# Test MSE: 0.4777
# Poisson likelihood: 0.0
# CE loss: 0.0
# Computing loss... 0
# Experiment 5972
# ...

# %%
# !python3 run_models.py --niters 100 -n 1000 -l 10 --dataset activity  --latent-ode --poisson
# Out:
# Sampling dataset of 1000 training examples
# Dataset PersonActivity
#     Number of datapoints: 1000
#     Root Location: data/PersonActivity
#     Max length: 50
#     Reduce: average
#
# /content/latent_ode/run_models.py
# run_models.py --niters 100 -n 1000 -l 10 --dataset activity --latent-ode --poisson
# Computing loss... 0
# Experiment 11415
# Epoch 0001 [Test seq (cond on sampled tp)] | Loss 2439.502686 | Likelihood -2455.343262 | KL fp 7.5977 | FP STD 0.8583|
# KL coef: 0.0
# Train loss (one batch): 2469.998779296875
# Train CE loss (one batch): 0.0
# Test MSE: 0.4918
# Poisson likelihood: 18.316953659057617
# CE loss: 0.0
# Computing loss... 0
# Experiment 11415
# Epoch 0002 [Test seq (cond on sampled tp)] | Loss 2108.816895 | Likelihood -2116.382324 | KL fp 9.3340 | FP STD 1.0250|
# KL coef: 0.0
# Train loss (one batch): 2059.712890625
# Train CE loss (one batch): 0.0
# Test MSE: 0.4240
# Poisson likelihood: 19.10309410095215
# CE loss: 0.0
# Computing loss... 0
# ...

# %%
# !python3 run_models.py --niters 100 -n 1000 -l 10 --dataset activity  --latent-ode
# Out:
# Sampling dataset of 1000 training examples
# Dataset PersonActivity
#     Number of datapoints: 1000
#     Root Location: data/PersonActivity
#     Max length: 50
#     Reduce: average
#
# /content/latent_ode/run_models.py
# run_models.py --niters 100 -n 1000 -l 10 --dataset activity --latent-ode
# Computing loss... 0
# Experiment 69220
# Epoch 0001 [Test seq (cond on sampled tp)] | Loss 2380.039062 | Likelihood -2385.800293 | KL fp 7.6857 | FP STD 0.2610|
# KL coef: 0.0
# Train loss (one batch): 2458.393798828125
# Train CE loss (one batch): 0.0
# Test MSE: 0.4779
# Poisson likelihood: 0.0
# CE loss: 0.0
# Computing loss... 0
# Experiment 69220
# Epoch 0002 [Test seq (cond on sampled tp)] | Loss 2087.069824 | Likelihood -2095.075928 | KL fp 8.6045 | FP STD 0.2182|
# KL coef: 0.0
# Train loss (one batch): 2005.34326171875
# Train CE loss (one batch): 0.0
# Test MSE: 0.4198
# Poisson likelihood: 0.0
# CE loss: 0.0
# Computing loss... 0
# Experiment 69220
# ...

# %%
# !python3 run_models.py\
 --niters 200 -n 10000 -l 15 --dataset activity\
  --latent-ode --rec-dims 100 --rec-layers 4 --gen-layers 2 \
  --units 500 --gru-units 50 --classif  --linear-classif\
